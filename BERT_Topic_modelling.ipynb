# %%
# Install bertopic
# !pip install bertopic
# Install older version of joblib
# !pip install --upgrade joblib==1.1.0
# Data processing
import pandas as pd
import numpy as np

# Text preprocessiong
import nltk
nltk.download('stopwords')
nltk.download('omw-1.4')
nltk.download('wordnet')
wn = nltk.WordNetLemmatizer()
from transformers import BERTopicModel

# Topic model
from pip import BERTopic

# Dimension reduction
from umap import UMAP
# Out:
# Collecting bertopic
#   Using cached bertopic-0.12.0-py2.py3-none-any.whl (90 kB)
# Collecting umap-learn>=0.5.0
#   Using cached umap_learn-0.5.3-py3-none-any.whl
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from bertopic) (1.2.0)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from bertopic) (1.23.5)
# Collecting sentence-transformers>=0.4.1
#   Using cached sentence_transformers-2.2.2-py3-none-any.whl
# Requirement already satisfied: pandas>=1.1.5 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from bertopic) (1.5.1)
# Requirement already satisfied: plotly>=4.7.0 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from bertopic) (5.11.0)
# Collecting hdbscan>=0.8.28
#   Using cached hdbscan-0.8.29.tar.gz (5.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pyyaml<6.0
#   Using cached PyYAML-5.4.1-cp39-cp39-win_amd64.whl (213 kB)
# Requirement already satisfied: tqdm>=4.41.1 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from bertopic) (4.64.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from hdbscan>=0.8.28->bertopic) (1.9.3)
# Requirement already satisfied: joblib>=1.0 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from hdbscan>=0.8.28->bertopic) (1.1.0)
# Collecting cython>=0.27
#   Using cached Cython-0.29.32-py2.py3-none-any.whl (986 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from pandas>=1.1.5->bertopic) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from plotly>=4.7.0->bertopic) (8.1.0)
# Collecting joblib>=1.0
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (0.11.1)
# Requirement already satisfied: nltk in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (3.7)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.97-cp39-cp39-win_amd64.whl (1.1 MB)
# Collecting torch>=1.6.0
#   Using cached torch-1.13.1-cp39-cp39-win_amd64.whl (162.5 MB)
# Collecting torchvision
#   Using cached torchvision-0.14.1-cp39-cp39-win_amd64.whl (1.1 MB)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from sentence-transformers>=0.4.1->bertopic) (4.25.1)
# Requirement already satisfied: colorama in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from tqdm>=4.41.1->bertopic) (0.4.6)
# Collecting numba>=0.49
#   Using cached numba-0.56.4-cp39-cp39-win_amd64.whl (2.5 MB)
# Collecting pynndescent>=0.5
#   Using cached pynndescent-0.5.8-py3-none-any.whl
# Requirement already satisfied: packaging>=20.9 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.4.0)
# Requirement already satisfied: filelock in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.8.2)
# Requirement already satisfied: requests in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.28.1)
# Requirement already satisfied: setuptools in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (60.2.0)
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Using cached llvmlite-0.39.1-cp39-cp39-win_amd64.whl (23.2 MB)
# Requirement already satisfied: six>=1.5 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.13.2)
# Requirement already satisfied: click in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (9.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.13)
# Building wheels for collected packages: hdbscan
#   Building wheel for hdbscan (pyproject.toml): started
#   Building wheel for hdbscan (pyproject.toml): finished with status 'error'
# Failed to build hdbscan
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\USER\Desktop\School Work\COM 726\venv\Scripts\python.exe' 'C:\Users\USER\Desktop\School Work\COM 726\venv\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\USER\AppData\Local\Temp\tmpgq2judco'
#        cwd: C:\Users\USER\AppData\Local\Temp\pip-install-cfjj9u69\hdbscan_1c1d3467377d4ab59f32c4c71fdb0736
#   Complete output (105 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-39
#   creating build\lib.win-amd64-cpython-39\hdbscan
#   copying hdbscan\flat.py -> build\lib.win-amd64-cpython-39\hdbscan
#   copying hdbscan\hdbscan_.py -> build\lib.win-amd64-cpython-39\hdbscan
#   copying hdbscan\plots.py -> build\lib.win-amd64-cpython-39\hdbscan
#   copying hdbscan\prediction.py -> build\lib.win-amd64-cpython-39\hdbscan
#   copying hdbscan\robust_single_linkage_.py -> build\lib.win-amd64-cpython-39\hdbscan
#   copying hdbscan\validity.py -> build\lib.win-amd64-cpython-39\hdbscan
#   copying hdbscan\__init__.py -> build\lib.win-amd64-cpython-39\hdbscan
#   creating build\lib.win-amd64-cpython-39\hdbscan\tests
#   copying hdbscan\tests\test_flat.py -> build\lib.win-amd64-cpython-39\hdbscan\tests
#   copying hdbscan\tests\test_hdbscan.py -> build\lib.win-amd64-cpython-39\hdbscan\tests
#   copying hdbscan\tests\test_prediction_utils.py -> build\lib.win-amd64-cpython-39\hdbscan\tests
#   copying hdbscan\tests\test_rsl.py -> build\lib.win-amd64-cpython-39\hdbscan\tests
#   copying hdbscan\tests\__init__.py -> build\lib.win-amd64-cpython-39\hdbscan\tests
#   running build_ext
#   cythoning hdbscan/_hdbscan_tree.pyx to hdbscan\_hdbscan_tree.c
#   C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\USER\AppData\Local\Temp\pip-install-cfjj9u69\hdbscan_1c1d3467377d4ab59f32c4c71fdb0736\hdbscan\_hdbscan_tree.pyx
#     tree = Parsing.p_module(s, pxd, full_module_name)
#   cythoning hdbscan/_hdbscan_linkage.pyx to hdbscan\_hdbscan_linkage.c
#   C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\USER\AppData\Local\Temp\pip-install-cfjj9u69\hdbscan_1c1d3467377d4ab59f32c4c71fdb0736\hdbscan\_hdbscan_linkage.pyx
#     tree = Parsing.p_module(s, pxd, full_module_name)
#   cythoning hdbscan/_hdbscan_boruvka.pyx to hdbscan\_hdbscan_boruvka.c
#   C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\USER\AppData\Local\Temp\pip-install-cfjj9u69\hdbscan_1c1d3467377d4ab59f32c4c71fdb0736\hdbscan\_hdbscan_boruvka.pyx
#     tree = Parsing.p_module(s, pxd, full_module_name)
#   cythoning hdbscan/_hdbscan_reachability.pyx to hdbscan\_hdbscan_reachability.c
#   C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\USER\AppData\Local\Temp\pip-install-cfjj9u69\hdbscan_1c1d3467377d4ab59f32c4c71fdb0736\hdbscan\_hdbscan_reachability.pyx
#     tree = Parsing.p_module(s, pxd, full_module_name)
#   cythoning hdbscan/_prediction_utils.pyx to hdbscan\_prediction_utils.c
#   C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\USER\AppData\Local\Temp\pip-install-cfjj9u69\hdbscan_1c1d3467377d4ab59f32c4c71fdb0736\hdbscan\_prediction_utils.pyx
#     tree = Parsing.p_module(s, pxd, full_module_name)
#   cythoning hdbscan/dist_metrics.pyx to hdbscan\dist_metrics.c
#   C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\USER\AppData\Local\Temp\pip-install-cfjj9u69\hdbscan_1c1d3467377d4ab59f32c4c71fdb0736\hdbscan\dist_metrics.pxd
#     tree = Parsing.p_module(s, pxd, full_module_name)
#   building 'hdbscan._hdbscan_tree' extension
#   Traceback (most recent call last):
#     File "C:\Users\USER\Desktop\School Work\COM 726\venv\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 363, in <module>
#       main()
#     File "C:\Users\USER\Desktop\School Work\COM 726\venv\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 345, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#     File "C:\Users\USER\Desktop\School Work\COM 726\venv\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 261, in build_wheel
#       return _build_backend().build_wheel(wheel_directory, config_settings,
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\build_meta.py", line 413, in build_wheel
#       return self._build_with_temp_dir(['bdist_wheel'], '.whl',
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\build_meta.py", line 398, in _build_with_temp_dir
#       self.run_setup()
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\build_meta.py", line 484, in run_setup
#       super(_BuildMetaLegacyBackend,
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\build_meta.py", line 335, in run_setup
#       exec(code, locals())
#     File "<string>", line 96, in <module>
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\__init__.py", line 87, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#       return run_commands(dist)
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#       dist.run_commands()
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\dist.py", line 1208, in run_command
#       super().run_command(command)
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\wheel\bdist_wheel.py", line 325, in run
#       self.run_command("build")
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\dist.py", line 1208, in run_command
#       super().run_command(command)
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\_distutils\command\build.py", line 132, in run
#       self.run_command(cmd_name)
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\dist.py", line 1208, in run_command
#       super().run_command(command)
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "<string>", line 26, in run
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\Cython\Distutils\old_build_ext.py", line 186, in run
#       _build_ext.build_ext.run(self)
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\_distutils\command\build_ext.py", line 346, in run
#       self.build_extensions()
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\Cython\Distutils\old_build_ext.py", line 195, in build_extensions
#       _build_ext.build_ext.build_extensions(self)
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\_distutils\command\build_ext.py", line 468, in build_extensions
#       self._build_extensions_serial()
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\_distutils\command\build_ext.py", line 494, in _build_extensions_serial
#       self.build_extension(ext)
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\_distutils\command\build_ext.py", line 549, in build_extension
#       objects = self.compiler.compile(
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\_distutils\_msvccompiler.py", line 344, in compile
#       self.initialize()
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\_distutils\_msvccompiler.py", line 253, in initialize
#       vc_env = _get_vc_env(plat_spec)
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\msvc.py", line 214, in msvc14_get_vc_env
#       return _msvc14_get_vc_env(plat_spec)
#     File "C:\Users\USER\AppData\Local\Temp\pip-build-env-n5zqut6f\overlay\Lib\site-packages\setuptools\msvc.py", line 168, in _msvc14_get_vc_env
#       raise distutils.errors.DistutilsPlatformError(
#   setuptools._distutils.errors.DistutilsPlatformError: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for hdbscan
# ERROR: Could not build wheels for hdbscan, which is required to install pyproject.toml-based projects
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\USER\Desktop\School Work\COM 726\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: joblib==1.1.0 in c:\users\user\desktop\school work\com 726\venv\lib\site-packages (1.1.0)
# WARNING: You are using pip version 21.3.1; however, version 22.3.1 is available.
# You should consider upgrading via the 'C:\Users\USER\Desktop\School Work\COM 726\venv\Scripts\python.exe -m pip install --upgrade pip' command.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [6], line 15
#      13 nltk.download('wordnet')
#      14 wn = nltk.WordNetLemmatizer()
# ---> 15 from transformers import BERTopicModel
#      17 # Topic model
#      18 from bertopic import BERTopic
#
# ImportError: cannot import name 'BERTopicModel' from 'transformers' (C:\Users\USER\Desktop\School Work\COM 726\venv\lib\site-packages\transformers\__init__.py)
